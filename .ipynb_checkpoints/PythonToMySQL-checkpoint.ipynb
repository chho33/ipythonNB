# %%
import requests
import shutil
import MySQLdb
import sqlite3 as lite
response = requests.get("http://image.wenweipo.com/2009new/paper/logo2.jpg",stream=True)
#print response
f = open('image.png','wb')
shutil.copyfileobj(response.raw,f)
f.close()
db =MySQLdb.connect(host='localhost',user="root",passwd="",db="practice",charset='utf8')
cur = db.cursor()
f = open('image.png','rb')
ablob = f.read()
#ablob = f.raw.read()    # why not??
f.close()
#cur.execute('insert into blobTable(photo) values(?)',[ablob])
#cur.execute('insert into blobTable(photo) values(?)',[MySQLdb.Binary(ablob)])
#print MySQLdb.Binary(ablob)
cur.execute('insert into blobTable(photo) values(%s)',[MySQLdb.Binary(ablob)])
db.commit()
db.close()

# %%
url="https://www.ptt.cc/bbs/Gossiping/index.html"
headers = {'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.152 Safari/537.36"',
           ':host':'www.ptt.cc',
           ':method':'GET',
           ':path':'/bbs/Gossiping/index.html',
           ':scheme':'https',
           ':version':'HTTP/1.1',
           'referer':'https://www.ptt.cc/hotboard.html',
           'accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
           'accept-encoding':'gzip, deflate, sdch',
           'cache-control':'max-age=0',
           'cookie':'over18=1; __utma=156441338.1800879024.1398650876.1432257197.1432373701.138; __utmc=156441338; __utmz=156441338.1432373701.138.124.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not%20provided)'
          }  # 加 cookie才有用 why?
res = requests.get(url, headers=headers)
print res.text
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8" />
#
#
# <meta name="viewport" content="width=device-width">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.13/bbs-common.css" />
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.13/bbs.css" media="screen" />
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.13/pushstream.css" media="screen" />
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.13/bbs-print.css" media="print" />
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/v2.13/bbs.js"></script>
#
#
#
#
# <script type="text/javascript">
#
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-32365737-1']);
#   _gaq.push(['_setDomainName', 'ptt.cc']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
# ...

# %%
r = requests.get('https://api.github.com/events', stream=True)
r.raw
r.raw.read(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-35aaeede3ad3> in <module>()
# ----> 1 r = requests.get('https://api.github.com/events', stream=True)
#       2 r.raw
#       3 r.raw.read(10)
#
# NameError: name 'requests' is not defined

# %%
import MySQLdb
dbname="practice"
db = MySQLdb.connect(host='localhost',user="root",passwd="oblivn0374",db=dbname,charset="utf8")
cur = db.cursor()
#cur.execute("ALTER DATABASE '%s' CHARACTER SET 'utf8' COLLATE 'utf8_unicode_ci'" % dbname)
#cur.execute("")
cur.execute('insert into hotels(hotelid,hotelname) values(%s,"%s")',[2,"中文"])
#cur.execute('select * from test(title)')
db.commit()
db.close()

# %% [markdown]
# ## 連承德

# %%
import MySQLdb
dbname="news"
host="10.120.30.1"
password=""
port= 3306
db = MySQLdb.connect(host=host,user="root",port=port,passwd="",db=dbname,charset="utf8")
cur = db.cursor()
cur.execute("select * from news")
db.commit()
